# %% [markdown]
# # Part 1: Data Acquisition & Understanding
#
# 1 Load the Wine dataset from sklearn and inspect its structure.
#
# 2 Create a DataFrame with all features and a numeric target column called class_id.
#
# 3 Add a class_name column using target names.
#
# 4 Check for missing values, class balance, and feature ranges.

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
from sklearn.datasets import load_wine
wine= load_wine(as_frame= True)
df = wine.data

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
df.shape
# Out:
# (178, 13)

# %%
df.isnull().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# dtype: int64

# %%
df.value_counts()
# Out:
# alcohol  malic_acid  ash   alcalinity_of_ash  magnesium  total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity  hue   od280/od315_of_diluted_wines  proline
# 11.03    1.51        2.20  21.5               85.0       2.46           2.17        0.52                  2.01             1.90             1.71  2.87                          407.0      1
# 13.68    1.83        2.36  17.2               104.0      2.42           2.69        0.42                  1.97             3.84             1.23  2.87                          990.0      1
# 13.40    3.91        2.48  23.0               102.0      1.80           0.75        0.43                  1.41             7.30             0.70  1.56                          750.0      1
#          4.60        2.86  25.0               112.0      1.98           0.96        0.27                  1.11             8.50             0.67  1.92                          630.0      1
# ...

# %%
X, y = load_wine(return_X_y = True)

# %%
target_names = wine.target_names
df['class_id'] = y
df['class_name'] = [target_names[i] for i in y]

# %% [markdown]
# # Part 2: Exploratory Data Visualization
#
# 1 Create a pairplot using four selected features colored by class_name.
#
# 2 Generate a correlation heatmap and identify strongly correlated features.
#
# 3 Create boxplots for two features grouped by class.

# %%
sns.pairplot(df, hue='class_name', corner=True, height=2.5)
plt.suptitle("pairplot showing relationships between features", y=1.02)
plt.show()

# %%
corr = df.select_dtypes(include=[np.number]).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.suptitle("heatmap and identify strongly correlated features")
plt.show()

# %%
sns.boxplot(x='nonflavanoid_phenols', y='proanthocyanins', data=df)
plt.suptitle("boxplots for two features grouped by class")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Part 3: Data Preparation
#
# 1 Define feature matrix X and target vector y.
#
# 2 Split the dataset into training (75%) and testing (25%) sets using stratification.
#
# 3 Apply feature scaling where appropriate and explain why.

# %%
X = df[wine.feature_names]
y = df['class_id']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=9)

# %%
from sklearn.preprocessing import StandardScaler

# %%
StandardScaler()
# Out:
# StandardScaler()

# %% [markdown]
# # Part 4: Model Training
#
# 1 Train a KNN classifier with n_neighbors=7 using scaled data.
#
# 2 Train a Decision Tree classifier with max_depth=4 using unscaled data.
#
# 3 Train a Logistic Regression model with max_iter=300 using scaled data.

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7)

# %%
from sklearn.tree import DecisionTreeClassifier
dt_clf = DecisionTreeClassifier(max_depth=4)
dt_clf
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
from sklearn.linear_model import LogisticRegression
log_reg= LogisticRegression()

# %% [markdown]
# # Part 5: Model Evaluation
#
# 1 Create and visualize a confusion matrix for the best model.
#
# 2 Generate a classification report and interpret the results.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = dt_clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp.plot()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class_0       0.94      1.00      0.97        15
#      class_1       0.94      0.94      0.94        18
#      class_2       1.00      0.92      0.96        12
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.95      0.96        45
# weighted avg       0.96      0.96      0.96        45
